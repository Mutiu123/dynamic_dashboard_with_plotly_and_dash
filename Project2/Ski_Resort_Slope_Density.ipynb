# %% [markdown]
# ##### **Application contain a density mapbox graph that displays colour intensity based on Total slopes.**
# - Add a slider to the application that filters the resorts mapped to those with a Price below the value selected in the slider.
# - Add a radio button that toggles between resorts with night skiing.
# - Consider making the title dynamic based on the price input.

# %%
from jupyter_dash import jupyter_dash
